# %% [markdown]
# This notebook will be mainly used for the capstone project.

# %%
import pandas as pd
# Out:
# Waiting for a Spark session to start...
# Spark Initialization Done! ApplicationId = app-20201028012931-0000
# KERNEL_ID = 2a5e1b96-9845-4955-b017-5037e338c137

# %%
import numpy as np

# %%
print ("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %%
import json

# %%
# !conda update -n base -c defaults conda
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/ibm/conda/miniconda
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.10.14 |                0         121 KB
#     certifi-2020.6.20          |   py37h06a4308_2         149 KB
#     conda-4.9.1                |   py37h06a4308_0         2.9 MB
#     conda-package-handling-1.7.2|   py37h03888b9_0         885 KB
#     openssl-1.1.1h             |       h7b6447c_0         2.5 MB
#     ------------------------------------------------------------
#                                            Total:         6.5 MB
#
# The following packages will be REMOVED:
#
#   asn1crypto-1.3.0-py37_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                               2020.7.22-0 --> 2020.10.14-0
# ...

# %%
# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/spark/shared/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.6.20  |       hecda079_0         145 KB  conda-forge
#     certifi-2020.6.20          |   py37he5f6b98_2         151 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-2.0.0                |     pyh9f0ad1d_0          63 KB  conda-forge
#     openssl-1.1.1h             |       h516909a_0         2.1 MB  conda-forge
#     python_abi-3.7             |          1_cp37m           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
# ...

# %%
import requests
from pandas.io.json import json_normalize

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
from sklearn.cluster import KMeans

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/spark/shared/conda/envs/python
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     attrs-20.2.0               |     pyh9f0ad1d_0          41 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     brotlipy-0.7.0             |py37hb5d75c8_1001         346 KB  conda-forge
#     cffi-1.14.3                |   py37he30daa8_0         223 KB
#     chardet-3.0.4              |py37he5f6b98_1008         170 KB  conda-forge
#     cryptography-3.2           |   py37hff6837a_0         624 KB  conda-forge
# ...

# %%
import bs4

# %%
from urllib.request import urlopen as uop

# %%
from bs4 import BeautifulSoup

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %%
url
# Out:
# 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %%
uclient = uop(url)
page_html = uclient.read()
uclient.close()

# %%
table_class = 'wikitable sortable'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
congress_table = soup.find('table', attrs = {'class': table_class})
df = pd.read_html(str(congress_table))
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 500)
pd.set_option('display.min_rows', 200)
pd.set_option('display.max_colwidth', 80)
pd.set_option('display.width', 120)
pd.set_option('expand_frame_repr', True)
df = df[0]
df
# Out:
#     Postal Code           Borough                                                                    Neighbourhood
# 0           M1A      Not assigned                                                                     Not assigned
# 1           M2A      Not assigned                                                                     Not assigned
# 2           M3A        North York                                                                        Parkwoods
# 3           M4A        North York                                                                 Victoria Village
# 4           M5A  Downtown Toronto                                                        Regent Park, Harbourfront
# 5           M6A        North York                                                 Lawrence Manor, Lawrence Heights
# 6           M7A  Downtown Toronto                                      Queen's Park, Ontario Provincial Government
# ...

# %% [markdown]
# Dropping cells without borough

# %%
df = df[df.Borough != 'Not assigned'].reset_index(drop=True)

# %%
df
# Out:
#     Postal Code           Borough                                                                    Neighbourhood
# 0           M3A        North York                                                                        Parkwoods
# 1           M4A        North York                                                                 Victoria Village
# 2           M5A  Downtown Toronto                                                        Regent Park, Harbourfront
# 3           M6A        North York                                                 Lawrence Manor, Lawrence Heights
# 4           M7A  Downtown Toronto                                      Queen's Park, Ontario Provincial Government
# 5           M9A         Etobicoke                                          Islington Avenue, Humber Valley Village
# 6           M1B       Scarborough                                                                   Malvern, Rouge
# ...

# %% [markdown]
# Grouping the different neighborhoods and separe them with a comma

# %%
df = df.groupby(['Postal Code','Borough'], as_index=False).agg(lambda x: ','.join(x))

# %%
df
# Out:
#     Postal Code           Borough                                                                    Neighbourhood
# 0           M1B       Scarborough                                                                   Malvern, Rouge
# 1           M1C       Scarborough                                           Rouge Hill, Port Union, Highland Creek
# 2           M1E       Scarborough                                                Guildwood, Morningside, West Hill
# 3           M1G       Scarborough                                                                           Woburn
# 4           M1H       Scarborough                                                                        Cedarbrae
# 5           M1J       Scarborough                                                              Scarborough Village
# 6           M1K       Scarborough                                      Kennedy Park, Ionview, East Birchmount Park
# ...

# %%
print("Shape: ", df.shape)
# Out:
# Shape:  (103, 3)

# %% [markdown]
# Get the latitude and the longitude coordinates of each neighborhood

# %%
import os

# %%
pwd
# Out:
# '/home/spark/shared'

# %%
import csv
csv_path = '/Users/donaldclovisaba/Desktop/projects/Geospatial_Coordinates.csv'
df_geo_coor = pd.read_csv(csv_path)
df_geo_coor.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-a4a0f71cd16d> in <module>()
#       1 import csv
#       2 csv_path = '/Users/donaldclovisaba/Desktop/projects/Geospatial_Coordinates.csv'
# ----> 3 df_geo_coor = pd.read_csv(csv_path)
#       4 df_geo_coor.head()
#
# ...

# %%
df_toronto = pd.merge(df, df_geo_coor, how='left', left_on = 'PostalCode', right_on = 'Postal Code')
# remove the "Postal Code" column
df_toronto.drop("Postal Code", axis=1, inplace=True)
df_toronto.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-2bab9fcf4a9a> in <module>()
# ----> 1 df_toronto = pd.merge(df, df_geo_coor, how='left', left_on = 'PostalCode', right_on = 'Postal Code')
#       2 # remove the "Postal Code" column
#       3 df_toronto.drop("Postal Code", axis=1, inplace=True)
#       4 df_toronto.head()
#
# NameError: name 'df_geo_coor' is not defined

# %% [markdown]
# Getting the latitude and longitude values of Toronto

# %%
address = "Toronto, ON"

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto city are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto city are 43.6534817, -79.3839347.

# %% [markdown]
# Create map of Toronto using latitude and longitude values and add markers to the map

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)
for lat, lng, borough, neighborhood in zip(
        df_toronto['Latitude'], 
        df_toronto['Longitude'], 
        df_toronto['Borough'], 
        df_toronto['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  

map_toronto
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-666b8ed87f65> in <module>()
#       1 map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)
#       2 for lat, lng, borough, neighborhood in zip(
# ----> 3         df_toronto['Latitude'],
#       4         df_toronto['Longitude'],
#       5         df_toronto['Borough'],
#
# NameError: name 'df_toronto' is not defined
